# %%
#Task 1
print("hello world")
# Out:
# hello world

# %%
#Task 2
print(54+56)
# Out:
# 110

# %%
#Task 3
season= "Fall"
year=2022
print(season)
print(year)
# Out:
# Fall
# 2022

# %%
#Task 4
name=input("Enter a name: ")
print("Your name is", name)
# Out:
# Enter a name: Rahi
# Your name is Rahi

# %%
#Task 5
num_1=int(input("Enter the value of M: "))
num_2=int(input("Enter the value of N: "))
ans=num_1**num_2
#print(num_1,"^",num_2,":",ans)
#print(str(num_1),"^",str(num_2),":",str(ans))
print(str(num_1)+"^"+str(num_2)+":"+str(ans)) #afl;jad;flkajsd;l
#print(f"{num_1}^{num_2}: {ans}")
# Out:
# Enter the value of M: 5
# Enter the value of N: 2
# 5^2:25

# %%
#Task 6
weight=int(input("Enter the amount of Weight: "))
# floor_div= weight//4
# ans=floor_div*4
# print (f"You can carry maximum {ans}")
ans=weight-(weight%4)
print (f"You can carry maximum {ans}")
# Out:
# Enter the amount of Weight: 9
# You can carry maximum 8

# %%
#Task 7
num_1=int(input("Enter the value of A: "))
num_2=int(input("Enter the value of B: "))
num_3=int(input("Enter the value of C: "))
num_4=float(input("Enter the value of D: "))
# espo= num_1**num_3
# mul=num_2*num_1
# div= num_4/3
# ans= espo+mul-div
# print(int(ans))
ans=(num_1**num_3)+(num_2*num_1)-(num_4/3)
print(int(ans))
# Out:
# Enter the value of A: 2
# Enter the value of B: 6
# Enter the value of C: 8
# Enter the value of D: 1.3
# 267

# %%
#Task 8
num=int(input("Enter the chocolate number: "))
frds=num//3
left=num%3
print(f"Each friend will receive {frds} chocolate")
print(f"The number of remaining chocolates is {left}")
# Out:
# Enter the chocolate number: 90
# Each friend will receive 30 chocolate
# The number of remaining chocolates is 0

# %%
#Task 9
value_1=input("Enter the value of M: ")
value_2=input("Enter the value of N: ")
print(value_2+value_1)
# Out:
# Enter the value of M: Hello
# Enter the value of N: World
# WorldHello

# %%
#Task 10
sen=input("Enter a sentence: ")
#print(sen[0])
sen[0]
# Out:
# Enter a sentence: opiyutgfub
# 'o'

# %%
#Task 11
num=int(input("Enter a number: "))
# if num%2==0 :
#   print(True)
# else:
#   print (False)
check=num%2
print(check==0)
# Out:
# Enter a number: 9
# False
